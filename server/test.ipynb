# %%
from models.text_to_speech import TextToSpeechModel 
text_to_speech_model = TextToSpeechModel()
text_to_speech_model.load_speaker_embeddings()
audio = text_to_speech_model.synthesise("Hello world!")
print(audio, type(audio))
# Out:
# tensor([-3.6146e-04, -3.4390e-04,  2.1287e-04,  ..., -5.7624e-05,
#          9.3414e-05,  1.1220e-04])

# %%
from IPython.display import Audio
Audio(audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Use the sounddevice module
# http://python-sounddevice.readthedocs.io/en/0.3.10/

import numpy as np
import sounddevice as sd
import time

# Samples per second
rate=16000

# Frequency / pitch
freq_hz = 440.0

# Duration
duration_s = 5.0

# Attenuation so the sound is reasonable
atten = 0.3

# NumpPy magic to calculate the waveform
each_sample_number = np.arange(duration_s * rate)
waveform = np.sin(2 * np.pi * each_sample_number * freq_hz / rate)
waveform_quiet = waveform * atten
print(waveform_quiet)
# Out:
# [ 0.          0.05157873  0.10162138 ... -0.1486376  -0.10162138
#  -0.05157873]

# %%
# Play the waveform out the speakers
sd.play(audio, rate)
time.sleep(duration_s)
sd.stop()
